# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt


#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head(30)
# Out:
#          EIN                                               NAME  \
# 0   10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1   10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2   10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3   10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4   10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# 5   10556855  MINORITY ORGAN & TISSUE TRANSPLANT & EDUCATION...
# 6   10558440  FRIENDS OF ARTS COUNCIL OF GREATER DENHAM SPRI...
# 7   10566033                          ISRAEL EMERGENCY ALLIANCE
# 8   10570430                                   ARAMCO BRATS INC
# 9   10571689         INTERNATIONAL ASSOCIATION OF FIRE FIGHTERS
# 10  10573059                      KAI ELUA OUTRIGGER CANOE CLUB
# 11  10575727                                   HERITAGE ACADEMY
# 12  10583569                   THE UNITED STATES PONY CLUBS INC
# 13  10585206  DOMINION INTERNATIONAL NETWORK OF MINISTRIES &...
# 14  10585443                                   V O W FOUNDATION
# 15  10596727                     JOSEPH E PEEBLES JR FOUNDATION
# 16  10602428  WASHINGTON ASSOCIATION OF PHYSICIANS OF INDIAN...
# 17  10603214                   SAINT FRANCIS HOSPITAL SOUTH LLC
# 18  10604986         ANCHORAGE COMMUNITY MENTAL HEALTH SERVICES
# 19  10605038             HABITAT FOR HUMANITY INTERNATIONAL INC
# 20  10608689                      INTERNATIONAL FELINE SHOWCASE
# 21  10612407                   METAMORPHASIS POWERHOUSE COMPANY
# 22  10614724                           REACH FOR EXCELLENCE INC
# 23  10622557            INTERNATIONAL ASSOCIATION OF LIONS CLUB
# 24  10623527                   SONS OF CONFEDERATE VETERANS INC
# 25  10629331           MAGDALENA OLD TIMERS REUNION ASSOCIATION
# 26  10631060            INFRAGARD NATIONAL MEMBERS ALLIANCE INC
# 27  10635952                     POP WARNER LITTLE SCHOLARS INC
# 28  10637680        FLORIDA STATE UNIVERSITY ALUMNI ASSOCIATION
# 29  10637829       HAWAII TRAVEL & TOURISM RESEARCH ASSOCIATION
#
#    APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0               T10       Independent          C1000    ProductDev
# 1                T3       Independent          C2000  Preservation
# 2                T5  CompanySponsored          C3000    ProductDev
# 3                T3  CompanySponsored          C2000  Preservation
# 4                T3       Independent          C1000     Heathcare
# 5                T3       Independent          C1200  Preservation
# 6                T3       Independent          C1000  Preservation
# 7                T3       Independent          C2000  Preservation
# 8                T7       Independent          C1000    ProductDev
# 9                T5  CompanySponsored          C3000    ProductDev
# 10               T3       Independent          C1200  Preservation
# 11               T3       Independent          C2000  Preservation
# 12               T3  CompanySponsored          C1200  Preservation
# 13               T3       Independent          C2700  Preservation
# 14               T3       Independent          C1000  Preservation
# 15               T3       Independent          C1200  Preservation
# 16               T3       Independent          C2000  Preservation
# 17               T3       Independent          C1000     Heathcare
# 18               T3  CompanySponsored          C1000  Preservation
# 19               T3  CompanySponsored          C1000  Preservation
# 20               T4       Independent          C3000    ProductDev
# 21               T3       Independent          C1200  Preservation
# 22               T3       Independent          C7000  Preservation
# 23               T4  CompanySponsored          C3000    ProductDev
# 24               T3  CompanySponsored          C1200  Preservation
# 25               T4       Independent          C3000    ProductDev
# 26               T3  CompanySponsored          C1000  Preservation
# 27               T3  CompanySponsored          C2000  Preservation
# 28               T3  CompanySponsored          C2000  Preservation
# 29               T6       Independent          C2000    ProductDev
#
#     ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0    Association       1              0                      N      5000
# 1   Co-operative       1         1-9999                      N    108590
# 2    Association       1              0                      N      5000
# 3          Trust       1    10000-24999                      N      6692
# 4          Trust       1  100000-499999                      N    142590
# 5          Trust       1              0                      N      5000
# 6          Trust       1  100000-499999                      N     31452
# 7          Trust       1        10M-50M                      N   7508025
# 8          Trust       1         1-9999                      N     94389
# 9    Association       1              0                      N      5000
# 10         Trust       1    25000-99999                      N     69656
# 11         Trust       1  100000-499999                      N    165593
# 12   Association       1              0                      N      5000
# 13         Trust       1    25000-99999                      N      5301
# 14         Trust       1              0                      N      5000
# 15         Trust       1              0                      N      5000
# 16         Trust       1              0                      N      5000
# 17         Trust       1           50M+                      N  86380556
# 18         Trust       1              0                      N      5000
# 19         Trust       1  100000-499999                      N    376109
# 20         Trust       1              0                      N      5000
# 21         Trust       1              0                      N      5000
# 22         Trust       1  100000-499999                      N    318296
# 23   Association       1              0                      N      5000
# 24         Trust       1              0                      N      5000
# 25         Trust       1              0                      N      5000
# 26         Trust       1              0                      N      5000
# 27         Trust       1    25000-99999                      N     44004
# 28         Trust       1              0                      N      5000
# 29         Trust       1              0                      N      5000
#
#     IS_SUCCESSFUL
# 0               1
# 1               1
# 2               0
# 3               1
# 4               1
# 5               1
# 6               1
# 7               1
# 8               1
# 9               0
# 10              0
# 11              0
# 12              1
# 13              1
# 14              1
# 15              1
# 16              1
# 17              0
# 18              0
# 19              0
# 20              1
# 21              1
# 22              0
# 23              0
# 24              0
# 25              1
# 26              1
# 27              1
# 28              0
# 29              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=["EIN", "NAME"], inplace=True)

# %%
# Normalization
application_df['ASK_AMT_LOG'] = np.log(application_df['ASK_AMT'] + 1)

# %%
# Adjusted bins
bins = [0, 500, 2000, 10000, 50000, 200000, 1e6, 1e9]
labels = ['Very Low', 'Low', 'Somewhat Low', 'Medium', 'Somewhat High', 'High', 'Very High']

application_df['ASK_AMT'] = pd.cut(application_df['ASK_AMT'], bins=bins, labels=labels)

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T9', 'T13', 'T12', 'T2', 'T14', 'T25', 'T15', 'T29', 'T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_types_to_replace = classification_counts[classification_counts == 1].index.tolist()

for cls in classification_types_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls, "Other")

print(application_df['CLASSIFICATION'].value_counts())
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# Other       26
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1237        9
# C1235        9
# C7210        7
# C1720        6
# C2400        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C1267        2
# C1256        2
# C1234        2
# C1246        2
# C3200        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
cutoff = 12
classification_counts = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = classification_counts[classification_counts < cutoff].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls, "Other")

# Check to make sure binning was successful
print(application_df['CLASSIFICATION'].value_counts())
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# Other      129
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df_encoded = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
X = application_df_encoded.drop(['IS_SUCCESSFUL'], axis=1).values
y = application_df_encoded['IS_SUCCESSFUL'].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 120
hidden_nodes_layer2 = 60
hidden_nodes_layer3 = 20

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Another layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='tanh'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Dropout layer
nn.add(tf.keras.layers.Dropout(rate=0.2))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 120)               8640
#
#  dense_1 (Dense)             (None, 60)                7260
#
#  dense_2 (Dense)             (None, 20)                1220
#
#  dense_3 (Dense)             (None, 1)                 21
#
#  dropout (Dropout)           (None, 1)                 0
#
# =================================================================
# Total params: 17141 (66.96 KB)
# Trainable params: 17141 (66.96 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
history = nn.fit(X_train_scaled, y_train, epochs=100, batch_size=200, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/100
# 103/103 - 6s - loss: 2.1276 - accuracy: 0.6569 - val_loss: 0.5903 - val_accuracy: 0.7092 - 6s/epoch - 55ms/step
# Epoch 2/100
# 103/103 - 1s - loss: 2.0975 - accuracy: 0.6749 - val_loss: 0.5758 - val_accuracy: 0.7180 - 1s/epoch - 11ms/step
# Epoch 3/100
# 103/103 - 1s - loss: 2.1358 - accuracy: 0.6731 - val_loss: 0.5754 - val_accuracy: 0.7277 - 835ms/epoch - 8ms/step
# Epoch 4/100
# 103/103 - 1s - loss: 2.1612 - accuracy: 0.6739 - val_loss: 0.5740 - val_accuracy: 0.7223 - 1s/epoch - 11ms/step
# Epoch 5/100
# 103/103 - 1s - loss: 2.1237 - accuracy: 0.6765 - val_loss: 0.5712 - val_accuracy: 0.7182 - 1s/epoch - 11ms/step
# Epoch 6/100
# 103/103 - 1s - loss: 2.0445 - accuracy: 0.6807 - val_loss: 0.5801 - val_accuracy: 0.7143 - 942ms/epoch - 9ms/step
# Epoch 7/100
# 103/103 - 1s - loss: 2.0899 - accuracy: 0.6777 - val_loss: 0.5766 - val_accuracy: 0.7248 - 864ms/epoch - 8ms/step
# Epoch 8/100
# 103/103 - 1s - loss: 2.0945 - accuracy: 0.6792 - val_loss: 0.5738 - val_accuracy: 0.7209 - 1s/epoch - 11ms/step
# Epoch 9/100
# 103/103 - 1s - loss: 2.0757 - accuracy: 0.6827 - val_loss: 0.5671 - val_accuracy: 0.7293 - 877ms/epoch - 9ms/step
# Epoch 10/100
# 103/103 - 1s - loss: 2.0355 - accuracy: 0.6828 - val_loss: 0.5651 - val_accuracy: 0.7324 - 995ms/epoch - 10ms/step
# Epoch 11/100
# 103/103 - 1s - loss: 2.1354 - accuracy: 0.6787 - val_loss: 0.5745 - val_accuracy: 0.7110 - 812ms/epoch - 8ms/step
# Epoch 12/100
# 103/103 - 2s - loss: 2.0754 - accuracy: 0.6822 - val_loss: 0.5791 - val_accuracy: 0.7143 - 2s/epoch - 15ms/step
# Epoch 13/100
# 103/103 - 2s - loss: 2.1151 - accuracy: 0.6803 - val_loss: 0.5748 - val_accuracy: 0.7285 - 2s/epoch - 17ms/step
# Epoch 14/100
# 103/103 - 0s - loss: 2.0574 - accuracy: 0.6817 - val_loss: 0.5658 - val_accuracy: 0.7252 - 466ms/epoch - 5ms/step
# Epoch 15/100
# 103/103 - 0s - loss: 2.1073 - accuracy: 0.6803 - val_loss: 0.5725 - val_accuracy: 0.7230 - 451ms/epoch - 4ms/step
# Epoch 16/100
# 103/103 - 0s - loss: 2.1367 - accuracy: 0.6808 - val_loss: 0.5790 - val_accuracy: 0.7096 - 442ms/epoch - 4ms/step
# Epoch 17/100
# 103/103 - 0s - loss: 2.1330 - accuracy: 0.6814 - val_loss: 0.5889 - val_accuracy: 0.6937 - 448ms/epoch - 4ms/step
# Epoch 18/100
# 103/103 - 0s - loss: 2.0612 - accuracy: 0.6822 - val_loss: 0.5768 - val_accuracy: 0.7197 - 473ms/epoch - 5ms/step
# Epoch 19/100
# 103/103 - 0s - loss: 2.0623 - accuracy: 0.6840 - val_loss: 0.5715 - val_accuracy: 0.7263 - 450ms/epoch - 4ms/step
# Epoch 20/100
# 103/103 - 0s - loss: 2.0479 - accuracy: 0.6879 - val_loss: 0.5856 - val_accuracy: 0.7160 - 493ms/epoch - 5ms/step
# Epoch 21/100
# 103/103 - 0s - loss: 2.0334 - accuracy: 0.6899 - val_loss: 0.5716 - val_accuracy: 0.7281 - 476ms/epoch - 5ms/step
# Epoch 22/100
# 103/103 - 0s - loss: 2.0692 - accuracy: 0.6865 - val_loss: 0.5663 - val_accuracy: 0.7283 - 452ms/epoch - 4ms/step
# Epoch 23/100
# 103/103 - 0s - loss: 2.0540 - accuracy: 0.6882 - val_loss: 0.5741 - val_accuracy: 0.7304 - 458ms/epoch - 4ms/step
# Epoch 24/100
# 103/103 - 0s - loss: 2.1107 - accuracy: 0.6819 - val_loss: 0.5726 - val_accuracy: 0.7232 - 424ms/epoch - 4ms/step
# Epoch 25/100
# 103/103 - 0s - loss: 2.0924 - accuracy: 0.6822 - val_loss: 0.5740 - val_accuracy: 0.7205 - 454ms/epoch - 4ms/step
# Epoch 26/100
# 103/103 - 0s - loss: 2.0799 - accuracy: 0.6837 - val_loss: 0.5866 - val_accuracy: 0.6877 - 429ms/epoch - 4ms/step
# Epoch 27/100
# 103/103 - 0s - loss: 2.0559 - accuracy: 0.6840 - val_loss: 0.5820 - val_accuracy: 0.7153 - 447ms/epoch - 4ms/step
# Epoch 28/100
# 103/103 - 0s - loss: 2.0879 - accuracy: 0.6849 - val_loss: 0.5799 - val_accuracy: 0.7215 - 412ms/epoch - 4ms/step
# Epoch 29/100
# 103/103 - 0s - loss: 2.0670 - accuracy: 0.6865 - val_loss: 0.5737 - val_accuracy: 0.7219 - 442ms/epoch - 4ms/step
# Epoch 30/100
# 103/103 - 0s - loss: 2.0239 - accuracy: 0.6872 - val_loss: 0.5775 - val_accuracy: 0.7188 - 432ms/epoch - 4ms/step
# Epoch 31/100
# 103/103 - 0s - loss: 2.0560 - accuracy: 0.6877 - val_loss: 0.5669 - val_accuracy: 0.7298 - 487ms/epoch - 5ms/step
# Epoch 32/100
# 103/103 - 0s - loss: 2.0917 - accuracy: 0.6857 - val_loss: 0.5707 - val_accuracy: 0.7265 - 472ms/epoch - 5ms/step
# Epoch 33/100
# 103/103 - 0s - loss: 2.0703 - accuracy: 0.6860 - val_loss: 0.5755 - val_accuracy: 0.7191 - 499ms/epoch - 5ms/step
# Epoch 34/100
# 103/103 - 0s - loss: 2.0420 - accuracy: 0.6877 - val_loss: 0.5723 - val_accuracy: 0.7310 - 464ms/epoch - 5ms/step
# Epoch 35/100
# 103/103 - 1s - loss: 2.0707 - accuracy: 0.6839 - val_loss: 0.5794 - val_accuracy: 0.7067 - 677ms/epoch - 7ms/step
# Epoch 36/100
# 103/103 - 1s - loss: 2.0597 - accuracy: 0.6857 - val_loss: 0.5760 - val_accuracy: 0.7258 - 689ms/epoch - 7ms/step
# Epoch 37/100
# 103/103 - 1s - loss: 2.0609 - accuracy: 0.6883 - val_loss: 0.5740 - val_accuracy: 0.7199 - 665ms/epoch - 6ms/step
# Epoch 38/100
# 103/103 - 1s - loss: 2.0437 - accuracy: 0.6900 - val_loss: 0.5800 - val_accuracy: 0.7211 - 752ms/epoch - 7ms/step
# Epoch 39/100
# 103/103 - 0s - loss: 2.0970 - accuracy: 0.6863 - val_loss: 0.5765 - val_accuracy: 0.7090 - 459ms/epoch - 4ms/step
# Epoch 40/100
# 103/103 - 0s - loss: 2.0940 - accuracy: 0.6876 - val_loss: 0.5708 - val_accuracy: 0.7180 - 452ms/epoch - 4ms/step
# Epoch 41/100
# 103/103 - 0s - loss: 2.0173 - accuracy: 0.6893 - val_loss: 0.5844 - val_accuracy: 0.7197 - 427ms/epoch - 4ms/step
# Epoch 42/100
# 103/103 - 0s - loss: 2.1067 - accuracy: 0.6837 - val_loss: 0.5843 - val_accuracy: 0.7061 - 386ms/epoch - 4ms/step
# Epoch 43/100
# 103/103 - 0s - loss: 2.0470 - accuracy: 0.6914 - val_loss: 0.5681 - val_accuracy: 0.7283 - 450ms/epoch - 4ms/step
# Epoch 44/100
# 103/103 - 0s - loss: 2.0870 - accuracy: 0.6858 - val_loss: 0.5784 - val_accuracy: 0.7223 - 448ms/epoch - 4ms/step
# Epoch 45/100
# 103/103 - 0s - loss: 2.0173 - accuracy: 0.6939 - val_loss: 0.5711 - val_accuracy: 0.7300 - 462ms/epoch - 4ms/step
# Epoch 46/100
# 103/103 - 0s - loss: 2.0539 - accuracy: 0.6879 - val_loss: 0.5775 - val_accuracy: 0.7256 - 476ms/epoch - 5ms/step
# Epoch 47/100
# 103/103 - 0s - loss: 2.0506 - accuracy: 0.6855 - val_loss: 0.5804 - val_accuracy: 0.7246 - 460ms/epoch - 4ms/step
# Epoch 48/100
# 103/103 - 0s - loss: 2.0531 - accuracy: 0.6904 - val_loss: 0.5819 - val_accuracy: 0.7168 - 421ms/epoch - 4ms/step
# Epoch 49/100
# 103/103 - 0s - loss: 2.0584 - accuracy: 0.6894 - val_loss: 0.5776 - val_accuracy: 0.7230 - 409ms/epoch - 4ms/step
# Epoch 50/100
# 103/103 - 0s - loss: 2.0458 - accuracy: 0.6886 - val_loss: 0.5717 - val_accuracy: 0.7279 - 451ms/epoch - 4ms/step
# Epoch 51/100
# 103/103 - 0s - loss: 2.1084 - accuracy: 0.6884 - val_loss: 0.5793 - val_accuracy: 0.7242 - 468ms/epoch - 5ms/step
# Epoch 52/100
# 103/103 - 0s - loss: 2.1222 - accuracy: 0.6832 - val_loss: 0.5776 - val_accuracy: 0.7193 - 489ms/epoch - 5ms/step
# Epoch 53/100
# 103/103 - 0s - loss: 2.0563 - accuracy: 0.6891 - val_loss: 0.5766 - val_accuracy: 0.7123 - 481ms/epoch - 5ms/step
# Epoch 54/100
# 103/103 - 1s - loss: 2.0871 - accuracy: 0.6865 - val_loss: 0.5765 - val_accuracy: 0.7259 - 541ms/epoch - 5ms/step
# Epoch 55/100
# 103/103 - 0s - loss: 2.0746 - accuracy: 0.6874 - val_loss: 0.5717 - val_accuracy: 0.7293 - 474ms/epoch - 5ms/step
# Epoch 56/100
# 103/103 - 0s - loss: 2.0866 - accuracy: 0.6895 - val_loss: 0.5915 - val_accuracy: 0.7112 - 485ms/epoch - 5ms/step
# Epoch 57/100
# 103/103 - 0s - loss: 2.0747 - accuracy: 0.6893 - val_loss: 0.5822 - val_accuracy: 0.7207 - 441ms/epoch - 4ms/step
# Epoch 58/100
# 103/103 - 0s - loss: 2.0419 - accuracy: 0.6884 - val_loss: 0.5829 - val_accuracy: 0.7100 - 485ms/epoch - 5ms/step
# Epoch 59/100
# 103/103 - 0s - loss: 2.0531 - accuracy: 0.6924 - val_loss: 0.5765 - val_accuracy: 0.7201 - 431ms/epoch - 4ms/step
# Epoch 60/100
# 103/103 - 1s - loss: 2.0532 - accuracy: 0.6872 - val_loss: 0.5790 - val_accuracy: 0.7223 - 662ms/epoch - 6ms/step
# Epoch 61/100
# 103/103 - 1s - loss: 2.0832 - accuracy: 0.6860 - val_loss: 0.5804 - val_accuracy: 0.7170 - 695ms/epoch - 7ms/step
# Epoch 62/100
# 103/103 - 1s - loss: 2.0603 - accuracy: 0.6874 - val_loss: 0.5810 - val_accuracy: 0.7186 - 762ms/epoch - 7ms/step
# Epoch 63/100
# 103/103 - 1s - loss: 2.0788 - accuracy: 0.6901 - val_loss: 0.5792 - val_accuracy: 0.7145 - 649ms/epoch - 6ms/step
# Epoch 64/100
# 103/103 - 0s - loss: 2.0856 - accuracy: 0.6904 - val_loss: 0.5784 - val_accuracy: 0.7223 - 450ms/epoch - 4ms/step
# Epoch 65/100
# 103/103 - 0s - loss: 2.0476 - accuracy: 0.6905 - val_loss: 0.5780 - val_accuracy: 0.7289 - 471ms/epoch - 5ms/step
# Epoch 66/100
# 103/103 - 0s - loss: 2.1303 - accuracy: 0.6851 - val_loss: 0.5786 - val_accuracy: 0.7219 - 440ms/epoch - 4ms/step
# Epoch 67/100
# 103/103 - 0s - loss: 2.0659 - accuracy: 0.6898 - val_loss: 0.5770 - val_accuracy: 0.7261 - 403ms/epoch - 4ms/step
# Epoch 68/100
# 103/103 - 0s - loss: 2.0669 - accuracy: 0.6890 - val_loss: 0.5724 - val_accuracy: 0.7190 - 452ms/epoch - 4ms/step
# Epoch 69/100
# 103/103 - 0s - loss: 2.0493 - accuracy: 0.6906 - val_loss: 0.5731 - val_accuracy: 0.7267 - 439ms/epoch - 4ms/step
# Epoch 70/100
# 103/103 - 0s - loss: 2.0553 - accuracy: 0.6920 - val_loss: 0.5790 - val_accuracy: 0.7205 - 455ms/epoch - 4ms/step
# Epoch 71/100
# 103/103 - 0s - loss: 2.0334 - accuracy: 0.6898 - val_loss: 0.5722 - val_accuracy: 0.7277 - 445ms/epoch - 4ms/step
# Epoch 72/100
# 103/103 - 0s - loss: 2.0348 - accuracy: 0.6900 - val_loss: 0.5846 - val_accuracy: 0.7160 - 429ms/epoch - 4ms/step
# Epoch 73/100
# 103/103 - 0s - loss: 2.0196 - accuracy: 0.6924 - val_loss: 0.5823 - val_accuracy: 0.6989 - 445ms/epoch - 4ms/step
# Epoch 74/100
# 103/103 - 0s - loss: 2.0880 - accuracy: 0.6853 - val_loss: 0.5702 - val_accuracy: 0.7275 - 440ms/epoch - 4ms/step
# Epoch 75/100
# 103/103 - 0s - loss: 2.0762 - accuracy: 0.6879 - val_loss: 0.5723 - val_accuracy: 0.7293 - 453ms/epoch - 4ms/step
# Epoch 76/100
# 103/103 - 0s - loss: 2.0350 - accuracy: 0.6898 - val_loss: 0.5746 - val_accuracy: 0.7248 - 452ms/epoch - 4ms/step
# Epoch 77/100
# 103/103 - 1s - loss: 2.0404 - accuracy: 0.6865 - val_loss: 0.5869 - val_accuracy: 0.7123 - 512ms/epoch - 5ms/step
# Epoch 78/100
# 103/103 - 1s - loss: 2.0371 - accuracy: 0.6896 - val_loss: 0.5751 - val_accuracy: 0.7254 - 570ms/epoch - 6ms/step
# Epoch 79/100
# 103/103 - 0s - loss: 2.0696 - accuracy: 0.6863 - val_loss: 0.5782 - val_accuracy: 0.7252 - 489ms/epoch - 5ms/step
# Epoch 80/100
# 103/103 - 0s - loss: 2.1071 - accuracy: 0.6892 - val_loss: 0.5751 - val_accuracy: 0.7283 - 484ms/epoch - 5ms/step
# Epoch 81/100
# 103/103 - 0s - loss: 2.0853 - accuracy: 0.6893 - val_loss: 0.5749 - val_accuracy: 0.7250 - 460ms/epoch - 4ms/step
# Epoch 82/100
# 103/103 - 0s - loss: 2.0844 - accuracy: 0.6870 - val_loss: 0.5762 - val_accuracy: 0.7271 - 468ms/epoch - 5ms/step
# Epoch 83/100
# 103/103 - 0s - loss: 2.0644 - accuracy: 0.6910 - val_loss: 0.5742 - val_accuracy: 0.7259 - 439ms/epoch - 4ms/step
# Epoch 84/100
# 103/103 - 0s - loss: 2.0427 - accuracy: 0.6905 - val_loss: 0.5766 - val_accuracy: 0.7289 - 453ms/epoch - 4ms/step
# Epoch 85/100
# 103/103 - 1s - loss: 2.1202 - accuracy: 0.6891 - val_loss: 0.5825 - val_accuracy: 0.7261 - 686ms/epoch - 7ms/step
# Epoch 86/100
# 103/103 - 1s - loss: 2.0691 - accuracy: 0.6917 - val_loss: 0.5757 - val_accuracy: 0.7302 - 752ms/epoch - 7ms/step
# Epoch 87/100
# 103/103 - 1s - loss: 2.0637 - accuracy: 0.6913 - val_loss: 0.5828 - val_accuracy: 0.7223 - 765ms/epoch - 7ms/step
# Epoch 88/100
# 103/103 - 1s - loss: 2.0172 - accuracy: 0.6946 - val_loss: 0.5755 - val_accuracy: 0.7252 - 610ms/epoch - 6ms/step
# Epoch 89/100
# 103/103 - 0s - loss: 2.0999 - accuracy: 0.6895 - val_loss: 0.5818 - val_accuracy: 0.7228 - 449ms/epoch - 4ms/step
# Epoch 90/100
# 103/103 - 1s - loss: 2.0595 - accuracy: 0.6893 - val_loss: 0.5704 - val_accuracy: 0.7310 - 501ms/epoch - 5ms/step
# Epoch 91/100
# 103/103 - 0s - loss: 2.0858 - accuracy: 0.6917 - val_loss: 0.5770 - val_accuracy: 0.7281 - 458ms/epoch - 4ms/step
# Epoch 92/100
# 103/103 - 0s - loss: 2.0808 - accuracy: 0.6887 - val_loss: 0.5774 - val_accuracy: 0.7287 - 493ms/epoch - 5ms/step
# Epoch 93/100
# 103/103 - 0s - loss: 2.0369 - accuracy: 0.6907 - val_loss: 0.5752 - val_accuracy: 0.7294 - 471ms/epoch - 5ms/step
# Epoch 94/100
# 103/103 - 0s - loss: 2.1165 - accuracy: 0.6877 - val_loss: 0.5719 - val_accuracy: 0.7314 - 490ms/epoch - 5ms/step
# Epoch 95/100
# 103/103 - 0s - loss: 2.0368 - accuracy: 0.6926 - val_loss: 0.5701 - val_accuracy: 0.7326 - 433ms/epoch - 4ms/step
# Epoch 96/100
# 103/103 - 0s - loss: 2.0666 - accuracy: 0.6933 - val_loss: 0.5736 - val_accuracy: 0.7296 - 429ms/epoch - 4ms/step
# Epoch 97/100
# 103/103 - 0s - loss: 2.0390 - accuracy: 0.6939 - val_loss: 0.5805 - val_accuracy: 0.7291 - 451ms/epoch - 4ms/step
# Epoch 98/100
# 103/103 - 0s - loss: 2.0935 - accuracy: 0.6908 - val_loss: 0.5740 - val_accuracy: 0.7294 - 412ms/epoch - 4ms/step
# Epoch 99/100
# 103/103 - 0s - loss: 2.0562 - accuracy: 0.6944 - val_loss: 0.5734 - val_accuracy: 0.7324 - 472ms/epoch - 5ms/step
# Epoch 100/100
# 103/103 - 0s - loss: 2.0968 - accuracy: 0.6885 - val_loss: 0.5729 - val_accuracy: 0.7314 - 440ms/epoch - 4ms/step

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5880 - accuracy: 0.7159 - 439ms/epoch - 2ms/step
# Loss: 0.588024914264679, Accuracy: 0.7159183621406555

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
